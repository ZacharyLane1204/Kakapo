# %%
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt
from glob import glob
import lightkurve as lk

# %matplotlib widget

# %%
file = glob('/Users/zgl12/c16/211800000/31000/ktwo211831427-c16_lpd-targ.fits.gz')[0]
file
# Out:
# '/Users/zgl12/c16/211800000/31000/ktwo211831427-c16_lpd-targ.fits.gz'

# %%
tpf = lk.read(file, quality_bitmask=0)

# %%
tpf.flux.value.shape
# Out:
# (3894, 8, 9)

# %%
array = np.random.randn(100)

grad = np.gradient(array)

# %%
array.shape, grad.shape
# Out:
# ((100,), (100,))

# %%
plt.figure()
plt.plot(array)
plt.show()

plt.figure()
plt.plot(grad)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
